# %% [markdown]
# **DÖVLƏT MƏŞĞULLUQ AGENTLİYİ**
#
#
# ---

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
# %matplotlib inline

# %%
data = pd.read_excel('data.xlsx', sheet_name='Data')

# %%
data['Müraciət edən vətəndaşın eyniləşdirmə nömrəsi'].nunique()
# Out:
# 44103

# %%
data.groupby('Müraciət edilmiş filial')['Müraciət edilmiş filial'].count().sort_values( axis=0, ascending=False).tail(3)
# Out:
# Müraciət edilmiş filial
# Bakı İqtisadi rayonu         9
# Şərqi Zəngəzur İR            9
# Mil-Muğan İqtisadi rayonu    5
# Name: Müraciət edilmiş filial, dtype: int64

# %%
data.groupby('Xidmət')['Xidmət'].count().sort_values( axis=0, ascending=False).head(5)
# Out:
# Xidmət
# Haqqı ödənilən ictimai İşlər                        3964
# Özünüməşğulluq (kənd təsərrüfatı zərfləri üzrə )    3936
# Peşə yönümlü məsləhət                               3905
# Əməkhaqqının birgə maliyyələşdirilməsi              3893
# Təcrübə proqramlarının təşkili                      3888
# Name: Xidmət, dtype: int64

# %%
data.groupby('Təhsil səviyyəsi')['Təhsil səviyyəsi'].count().sort_values( axis=0, ascending=False)
# Out:
# Təhsil səviyyəsi
# Ümumi təhsil-tam orta təhsil                        6744
# Ali təhsil-bakalavriat                              4041
# Ümumi təhsil-ümumi orta təhsil                      1888
# Tam orta təhsil bazasında orta ixtisas təhsili      1560
# Orta ixtisas təhsili                                1556
# Ümumi orta təhsil bazasında orta ixtisas təhsili     869
# İlk peşə-ixtisas təhsili                             777
# Ali təhsil-bakalavriat, Ali təhsil-magistratura      321
# bakalavriat                                          302
# Ümumi təhsil-ibtidai təhsil                           27
# Name: Təhsil səviyyəsi, dtype: int64

# %%
data.groupby('Cins')['Müraciət edən vətəndaşın eyniləşdirmə nömrəsi'].count().sort_values( axis=0, ascending=False)
# Out:
# Cins
# 1    36075
# 0    13925
# Name: Müraciət edən vətəndaşın eyniləşdirmə nömrəsi, dtype: int64

# %%
man_per= (data[data['Cins']==1].shape[0]  *100)/(data['Cins'].shape[0])
man_per
# Out:
# 72.15

# %%
woman_per= (data[data['Cins']==0].shape[0]  *100)/(data['Cins'].shape[0])
woman_per
# Out:
# 27.85

# %%
data.head()
# Out:
#    Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                          1002307  2019-03-11 00:00:00
# 1                         15317345  2020-04-25 00:00:00
# 2                          1003198  2019-03-11 00:00:00
# 3                          1002647  2019-03-11 00:00:00
# 4                          1002701  2019-03-11 00:00:00
#
#    Müraciət edən vətəndaşın eyniləşdirmə nömrəsi Doğum tarixi  Cins  \
# 0                                          10012   1978-12-07     1
# 1                                          10037   1995-01-18     0
# 2                                          10084   1992-08-27     1
# 3                                          10148   1991-01-30     0
# 4                                          10150   2000-01-24     0
#
#   Ailə vəziyyəti                                            Xidmət  \
# 0           Evli              İşsizlikdən sığorta ödənişin təşkili
# 1           Evli              İşsizlikdən sığorta ödənişin təşkili
# ...

# %%
data.describe()
# Out:
#        Müraciətin eyniləşdirmə nömrəsi  \
# count                     5.000000e+04
# mean                      1.874039e+06
# std                       5.327916e+06
# min                       1.140000e+02
# 25%                       8.997550e+04
# 50%                       1.834010e+05
# 75%                       3.408008e+05
# max                       2.637714e+07
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi          Cins
# count                                   50000.000000  50000.000000
# mean                                    31981.831280      0.721500
# std                                     12751.562681      0.448265
# min                                     10001.000000      0.000000
# 25%                                     20910.750000      0.000000
# 50%                                     31933.500000      1.000000
# 75%                                     42992.250000      1.000000
# max                                     54103.000000      1.000000

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Müraciətin eyniləşdirmə nömrəsi                50000 non-null  int64
#  1   Müraciət tarixi                                49998 non-null  object
#  2   Müraciət edən vətəndaşın eyniləşdirmə nömrəsi  50000 non-null  int64
#  3   Doğum tarixi                                   49993 non-null  datetime64[ns]
#  4   Cins                                           50000 non-null  int64
#  5   Ailə vəziyyəti                                 49992 non-null  object
#  6   Xidmət                                         50000 non-null  object
#  7   Müraciət edilmiş filial                        50000 non-null  object
#  8   Təhsil səviyyəsi                               18085 non-null  object
# ...

# %%
data.isnull()
# Out:
#        Müraciətin eyniləşdirmə nömrəsi  Müraciət tarixi  \
# 0                                False            False
# 1                                False            False
# 2                                False            False
# 3                                False            False
# 4                                False            False
# ...                                ...              ...
# 49995                            False            False
# 49996                            False            False
# 49997                            False            False
# 49998                            False            False
# 49999                            False            False
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi  Doğum tarixi   Cins  \
# 0                                              False         False  False
# 1                                              False         False  False
# ...

# %%
data.isnull().sum()
# Out:
# Müraciətin eyniləşdirmə nömrəsi                      0
# Müraciət tarixi                                      2
# Müraciət edən vətəndaşın eyniləşdirmə nömrəsi        0
# Doğum tarixi                                         7
# Cins                                                 0
# Ailə vəziyyəti                                       8
# Xidmət                                               0
# Müraciət edilmiş filial                              0
# Təhsil səviyyəsi                                 31915
# Faktiki ünvan                                        0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='Blues')

# %%
# def impute_age(cols):
#     age = cols[9]
    
    
#     if pd.isnull(age) or age<=0:
#       return 32
#     if age>0 and age<10:
#       return 5
#     elif age>10 and age<20 :
#       return 15
#     elif age>20 and age<40 :
#       return 30
#     elif age>40 and age<60 :
#       return 50 
#     else:
#         return 65

# %%
#data['yaş'] = data['yaş'].apply(impute_age,axis=1)

# %%
data['yaş']=pd.to_datetime('today').year-pd.to_datetime(data['Doğum tarixi']).dt.year
# (pd.to_datetime('today').year-pd.to_datetime('1956-07-01').year)
data.head()
# Out:
#    Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                          1002307  2019-03-11 00:00:00
# 1                         15317345  2020-04-25 00:00:00
# 2                          1003198  2019-03-11 00:00:00
# 3                          1002647  2019-03-11 00:00:00
# 4                          1002701  2019-03-11 00:00:00
#
#    Müraciət edən vətəndaşın eyniləşdirmə nömrəsi Doğum tarixi  Cins  \
# 0                                          10012   1978-12-07     1
# 1                                          10037   1995-01-18     0
# 2                                          10084   1992-08-27     1
# 3                                          10148   1991-01-30     0
# 4                                          10150   2000-01-24     0
#
#   Ailə vəziyyəti                                            Xidmət  \
# 0           Evli              İşsizlikdən sığorta ödənişin təşkili
# 1           Evli              İşsizlikdən sığorta ödənişin təşkili
# ...

# %%
data['yaş'].mean()
# Out:
# 32.05952833396675

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Cins',y='yaş',data=data,palette='Blues_r')

# %%
data['yaş'].fillna(value=data['yaş'].mean(), inplace=True)

# %%
data['Təhsil səviyyəsi'].mode()
# Out:
# 0    Ümumi təhsil-tam orta təhsil
# dtype: object

# %%
data.isnull().sum()
# Out:
# Müraciətin eyniləşdirmə nömrəsi                      0
# Müraciət tarixi                                      2
# Müraciət edən vətəndaşın eyniləşdirmə nömrəsi        0
# Doğum tarixi                                         7
# Cins                                                 0
# Ailə vəziyyəti                                       8
# Xidmət                                               0
# Müraciət edilmiş filial                              0
# Təhsil səviyyəsi                                 31915
# Faktiki ünvan                                        0
# yaş                                                  0
# dtype: int64

# %%
data.drop('Təhsil səviyyəsi',axis=1,inplace=True)
data.dropna(inplace=True)
data.head()
# Out:
#    Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                          1002307  2019-03-11 00:00:00
# 1                         15317345  2020-04-25 00:00:00
# 2                          1003198  2019-03-11 00:00:00
# 3                          1002647  2019-03-11 00:00:00
# 4                          1002701  2019-03-11 00:00:00
#
#    Müraciət edən vətəndaşın eyniləşdirmə nömrəsi Doğum tarixi  Cins  \
# 0                                          10012   1978-12-07     1
# 1                                          10037   1995-01-18     0
# 2                                          10084   1992-08-27     1
# 3                                          10148   1991-01-30     0
# 4                                          10150   2000-01-24     0
#
#   Ailə vəziyyəti                                            Xidmət  \
# 0           Evli              İşsizlikdən sığorta ödənişin təşkili
# 1           Evli              İşsizlikdən sığorta ödənişin təşkili
# ...

# %%
data[data['yaş']<0]=32
data[data['yaş']<0]
# Out:
# Empty DataFrame
# Columns: [Müraciətin eyniləşdirmə nömrəsi, Müraciət tarixi, Müraciət edən vətəndaşın eyniləşdirmə nömrəsi, Doğum tarixi, Cins, Ailə vəziyyəti, Xidmət, Müraciət edilmiş filial, Faktiki ünvan, yaş]
# Index: []

# %%
data[data['yaş']>100]
# Out:
# Empty DataFrame
# Columns: [Müraciətin eyniləşdirmə nömrəsi, Müraciət tarixi, Müraciət edən vətəndaşın eyniləşdirmə nömrəsi, Doğum tarixi, Cins, Ailə vəziyyəti, Xidmət, Müraciət edilmiş filial, Faktiki ünvan, yaş]
# Index: []

# %%
data
# Out:
#        Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                              1002307  2019-03-11 00:00:00
# 1                             15317345  2020-04-25 00:00:00
# 2                              1003198  2019-03-11 00:00:00
# 3                              1002647  2019-03-11 00:00:00
# 4                              1002701  2019-03-11 00:00:00
# ...                                ...                  ...
# 49995                           567298  2019-01-17 00:00:00
# 49996                           569874  2019-01-18 00:00:00
# 49997                           570346  2019-01-31 00:00:00
# 49998                         21807075  2021-08-03 00:00:00
# 49999                           570370  2019-01-18 00:00:00
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 0                                              10012  1978-12-07 00:00:00
# 1                                              10037  1995-01-18 00:00:00
# ...

# %%
#distribution plot of age of the people
sns.displot(data['yaş'].dropna(), kde=False, bins=30, color='Blue')

# %%
plt.figure(figsize=(25, 7))
sns.countplot(x=data['yaş'],data=data,color="Blue")

# %%
from datetime import datetime    # To access datetime 
from pandas import Series        # To work on series 
# %matplotlib inline 
import warnings                   # To ignore the warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = data
dfle['Ailə vəziyyəti'] = le.fit_transform(dfle['Ailə vəziyyəti'].astype(str))
dfle
# Out:
#        Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                              1002307  2019-03-11 00:00:00
# 1                             15317345  2020-04-25 00:00:00
# 2                              1003198  2019-03-11 00:00:00
# 3                              1002647  2019-03-11 00:00:00
# 4                              1002701  2019-03-11 00:00:00
# ...                                ...                  ...
# 49995                           567298  2019-01-17 00:00:00
# 49996                           569874  2019-01-18 00:00:00
# 49997                           570346  2019-01-31 00:00:00
# 49998                         21807075  2021-08-03 00:00:00
# 49999                           570370  2019-01-18 00:00:00
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 0                                              10012  1978-12-07 00:00:00
# 1                                              10037  1995-01-18 00:00:00
# ...

# %%
dfle['Xidmət'] = le.fit_transform(dfle['Xidmət'].astype(str))
dfle
# Out:
#        Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                              1002307  2019-03-11 00:00:00
# 1                             15317345  2020-04-25 00:00:00
# 2                              1003198  2019-03-11 00:00:00
# 3                              1002647  2019-03-11 00:00:00
# 4                              1002701  2019-03-11 00:00:00
# ...                                ...                  ...
# 49995                           567298  2019-01-17 00:00:00
# 49996                           569874  2019-01-18 00:00:00
# 49997                           570346  2019-01-31 00:00:00
# 49998                         21807075  2021-08-03 00:00:00
# 49999                           570370  2019-01-18 00:00:00
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 0                                              10012  1978-12-07 00:00:00
# 1                                              10037  1995-01-18 00:00:00
# ...

# %%
dfle['Müraciət edilmiş filial'] = le.fit_transform(dfle['Müraciət edilmiş filial'].astype(str))
dfle
# Out:
#        Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                              1002307  2019-03-11 00:00:00
# 1                             15317345  2020-04-25 00:00:00
# 2                              1003198  2019-03-11 00:00:00
# 3                              1002647  2019-03-11 00:00:00
# 4                              1002701  2019-03-11 00:00:00
# ...                                ...                  ...
# 49995                           567298  2019-01-17 00:00:00
# 49996                           569874  2019-01-18 00:00:00
# 49997                           570346  2019-01-31 00:00:00
# 49998                         21807075  2021-08-03 00:00:00
# 49999                           570370  2019-01-18 00:00:00
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 0                                              10012  1978-12-07 00:00:00
# 1                                              10037  1995-01-18 00:00:00
# ...

# %%
dfle['Faktiki ünvan'] = le.fit_transform(dfle['Faktiki ünvan'].astype(str))
dfle
# Out:
#        Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                              1002307  2019-03-11 00:00:00
# 1                             15317345  2020-04-25 00:00:00
# 2                              1003198  2019-03-11 00:00:00
# 3                              1002647  2019-03-11 00:00:00
# 4                              1002701  2019-03-11 00:00:00
# ...                                ...                  ...
# 49995                           567298  2019-01-17 00:00:00
# 49996                           569874  2019-01-18 00:00:00
# 49997                           570346  2019-01-31 00:00:00
# 49998                         21807075  2021-08-03 00:00:00
# 49999                           570370  2019-01-18 00:00:00
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 0                                              10012  1978-12-07 00:00:00
# 1                                              10037  1995-01-18 00:00:00
# ...

# %%
train=dfle.iloc[0:40000,:]
test=dfle.iloc[40000:,:]
train
# Out:
#        Müraciətin eyniləşdirmə nömrəsi      Müraciət tarixi  \
# 0                              1002307  2019-03-11 00:00:00
# 1                             15317345  2020-04-25 00:00:00
# 2                              1003198  2019-03-11 00:00:00
# 3                              1002647  2019-03-11 00:00:00
# 4                              1002701  2019-03-11 00:00:00
# ...                                ...                  ...
# 40012                            78061  2019-03-05 00:00:00
# 40013                            78071  2019-03-25 00:00:00
# 40014                         13188756  2020-04-23 00:00:00
# 40015                            78173  2019-01-15 00:00:00
# 40016                            78221  2019-03-07 00:00:00
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 0                                              10012  1978-12-07 00:00:00
# 1                                              10037  1995-01-18 00:00:00
# ...

# %%
train[train['Müraciət tarixi']=='12.17.2019']
# Out:
#        Müraciətin eyniləşdirmə nömrəsi Müraciət tarixi  \
# 21605                             7619      12.17.2019
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 21605                                          17073  1997-06-17 00:00:00
#
#        Cins  Ailə vəziyyəti  Xidmət  Müraciət edilmiş filial  Faktiki ünvan  \
# 21605     1               3      13                        9          49246
#
#         yaş
# 21605  25.0

# %%
test[test['Müraciət tarixi']=='12.17.2019']
# Out:
# Empty DataFrame
# Columns: [Müraciətin eyniləşdirmə nömrəsi, Müraciət tarixi, Müraciət edən vətəndaşın eyniləşdirmə nömrəsi, Doğum tarixi, Cins, Ailə vəziyyəti, Xidmət, Müraciət edilmiş filial, Faktiki ünvan, yaş]
# Index: []

# %%
train.drop([21605],axis=0,inplace=True)

# %%
train[train['Müraciət tarixi']=='02.18.2021']
# Out:
#        Müraciətin eyniləşdirmə nömrəsi Müraciət tarixi  \
# 21658                         21567566      02.18.2021
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 21658                                          17194  1985-12-10 00:00:00
#
#        Cins  Ailə vəziyyəti  Xidmət  Müraciət edilmiş filial  Faktiki ünvan  \
# 21658     1               3      13                        4          29229
#
#         yaş
# 21658  37.0

# %%
train.drop([21658],axis=0,inplace=True)

# %%
train[train['Müraciət tarixi']=='04.29.2019']
# Out:
#        Müraciətin eyniləşdirmə nömrəsi Müraciət tarixi  \
# 21712                            50701      04.29.2019
#
#        Müraciət edən vətəndaşın eyniləşdirmə nömrəsi         Doğum tarixi  \
# 21712                                          17412  1984-04-02 00:00:00
#
#        Cins  Ailə vəziyyəti  Xidmət  Müraciət edilmiş filial  Faktiki ünvan  \
# 21712     1               3       8                        6          22546
#
#         yaş
# 21712  38.0

# %%
train.drop([21712],axis=0,inplace=True)

# %%
train['Müraciət tarixi'] = pd.to_datetime(train['Müraciət tarixi'], errors='coerce')

# %%
train_original=train.copy()
test_original=test.copy()

# %%
train['Müraciət tarixi'] = pd.to_datetime(train['Müraciət tarixi'],format='%Y-%m-%d') 
test['Müraciət tarixi'] = pd.to_datetime(test['Müraciət tarixi'],format='%d-%m-%Y %H:%M') 
test_original['Müraciət tarixi'] = pd.to_datetime(test_original['Müraciət tarixi'],format='%d-%m-%Y %H:%M') 
train_original['Müraciət tarixi'] = pd.to_datetime(train_original['Müraciət tarixi'],format='%d-%m-%Y %H:%M')

# %%
train['Müraciət tarixi']
# Out:
# 0       2019-03-11
# 1       2020-04-25
# 2       2019-03-11
# 3       2019-03-11
# 4       2019-03-11
#            ...
# 40012   2019-03-05
# 40013   2019-03-25
# 40014   2020-04-23
# 40015   2019-01-15
# 40016   2019-03-07
# Name: Müraciət tarixi, Length: 39997, dtype: datetime64[ns]

# %%
from datetime import datetime 
for i in (train, test, test_original, train_original):
    i['year']=i['Müraciət tarixi'].dt.year 
    i['month']=i['Müraciət tarixi'].dt.month 
    i['day']=i['Müraciət tarixi'].dt.day    
    i['Hour']=i['Müraciət tarixi'].dt.hour

# %%
train.groupby('year')['Müraciət edən vətəndaşın eyniləşdirmə nömrəsi'].count().plot.bar()

# %%
train.groupby('month')['Müraciət edən vətəndaşın eyniləşdirmə nömrəsi'].count().plot.bar()

# %%
temp=train.groupby(['year', 'month'])['Müraciət edən vətəndaşın eyniləşdirmə nömrəsi'].count() 
temp.plot(figsize=(15,5), title= 'Müraciət edən vətəndaşların sayı', fontsize=14)

# %%
train.groupby('day')['Müraciət edən vətəndaşın eyniləşdirmə nömrəsi'].count().plot.bar()

# %%
data.count()
# Out:
# Müraciətin eyniləşdirmə nömrəsi                  49983
# Müraciət tarixi                                  49983
# Müraciət edən vətəndaşın eyniləşdirmə nömrəsi    49983
# Doğum tarixi                                     49983
# Cins                                             49983
# Ailə vəziyyəti                                   49983
# Xidmət                                           49983
# Müraciət edilmiş filial                          49983
# Faktiki ünvan                                    49983
# yaş                                              49983
# dtype: int64
